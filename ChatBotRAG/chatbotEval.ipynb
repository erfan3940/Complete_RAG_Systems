# %% [markdown]
# ### Chatbot And RAG Evaluation
#
# 1. Creating a dataset with questions and their expected answers
# 2. Running your RAG application on those questions
# 3. Using evaluators to measure how well your application performed, looking at factors like:
#  - Answer relevance
#  - Answer accuracy
#  - Retrieval quality

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langsmith import Client
client = Client()
from groq import Groq

groq_client = Groq(
    # This is the default and can be omitted
    api_key=os.environ.get("GROQ_API"),
)

os.environ["LANGSMITH_API_KEY"]=os.getenv("LANGSMITH_API_KEY")
os.environ["LANGSMITH_TRACING"]="true"

# %%
from langsmith import Client

client = Client()

# Define dataset: these are your test cases
dataset_name = "MyChatbot Evaluation"
dataset = client.create_dataset(dataset_name)
client.create_examples(
    dataset_id=dataset.id,
    examples=[
        {
        "inputs": {"question": "LangChain چیست؟"},
        "outputs": {"answer": "چارچوبی برای ساخت برنامه‌های LLM"},
        },
        {
        "inputs": {"question": "LangSmith چیست؟"},
        "outputs": {"answer": "پلتفرمی برای مشاهده و ارزیابی برنامه‌های LLM"},
        },
        {
        "inputs": {"question": "OpenAI چیست؟"},
        "outputs": {"answer": "شرکتی که مدل‌های زبان بزرگ ایجاد می‌کند"},
        },
        {
        "inputs": {"question": "گوگل چیست؟"},
        "outputs": {"answer": "شرکتی که زبان‌های بزرگ ایجاد می‌کند"},
        },
        {
        "inputs": {"question": "Mistral چیست؟"},
        "outputs": {"answer":" شرکتی که زبان‌های بزرگ ایجاد می‌کند مدل‌ها"},
        }
        ]
        )
# Out:
# {'example_ids': ['390e9d8c-5afa-4da2-b4e4-0e30d399e58c',
#   'f82f7d92-5f15-45e6-87a3-f5b1ed8664ef',
#   '202def5a-b2b4-4324-816f-d130db654df8',
#   '675ed529-72b3-487d-a08b-a067d440711a',
#   '4daee9d6-3eb0-45dc-ab70-2c00a20e5422'],
#  'count': 5}

# %%
from openai import OpenAI
from langsmith import wrappers
import os

# ai_client = openai_client=wrappers.wrap_openai(openai.OpenAI())

eval_instructions = (
    "You are an expert professor specialized in grading students' answers to questions. "
    "Respond ONLY with CORRECT or INCORRECT."
)

def correctness(inputs: dict, outputs: dict, reference_outputs: dict) -> bool:
    user_content = f"""
You are grading the following question:
{inputs['question']}

Here is the real answer:
{reference_outputs['answer']}

You are grading the following predicted answer:
{outputs['response']}

Respond with CORRECT or INCORRECT:
Grade:
""".strip()

    response = groq_client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        temperature=0,
        messages=[
            {"role": "system", "content": eval_instructions},
            {"role": "user", "content": user_content},
        ],
    ).choices[0].message.content.strip()

    return response == "CORRECT"

# %%
def concision(outputs: dict, reference_outputs: dict) -> bool:
    return int(len(outputs["response"]) < 2 * len(reference_outputs["answer"]))

# %%
default_instructions = "Respond to the users question in a short, concise manner (one short sentence)."
def my_app(question: str, model: str = "llama-3.3-70b-versatile", instructions: str = default_instructions) -> str:
    return groq_client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role": "system", "content": instructions},
            {"role": "user", "content": question},
        ],
    ).choices[0].message.content

# %%
def ls_target(inputs: str) -> dict:
    return {"response": my_app(inputs["question"])}

# %%
experiment_results=client.evaluate(
    ls_target, ## Your AI system
    data="MyChatbot Evaluation",
    evaluators=[correctness,concision],
    experiment_prefix="groq-chatbot"
)
# Out:
# View the evaluation results for experiment: 'groq-chatbot-0a71485f' at:
# https://smith.langchain.com/o/2d81f2a4-dffa-456c-9c4b-a16f6ccc7ae8/datasets/856336c4-f610-4c69-8eaf-1b1099c222f7/compare?selectedSessions=004092b3-7940-4d79-95bd-ff8efc90d762
# 0it [00:00, ?it/s]

# %%
from groq import Groq
import os
client = Groq(
    # This is the default and can be omitted
    api_key=os.environ.get("GROQ_API"),
)
prompt = [{"role": "user", "content": "Come up with a new business idea for AI Agents"}]
stream = client.chat.completions.create(model="llama-3.3-70b-versatile", messages=prompt, stream=True)
    def event_stream(stream):
        for chunk in stream:
            text = chunk.choices[0].delta.content
            if text:
                lines = text.split("\n")
                for line in lines:
                    yield f"data: {line}\n"
                yield "\n"
print(event_stream(stream))
# Out:
# Here's a new business idea for AI agents:
#
# **Business Idea:** "DreamScout" - AI-Powered Personalized Travel Planning and Itinerary Builder
#
# **Description:** DreamScout is an AI-powered travel planning platform that utilizes machine learning algorithms to create personalized travel itineraries for users. The platform will use natural language processing (NLP) to understand users' preferences, interests, and budget constraints, and then generate customized travel plans that include destinations, activities, accommodations, and transportation options.
#
# **How it works:**
#
# 1. **User Input:** Users will input their travel preferences, interests, and budget constraints through a conversational interface (e.g., chatbot or voice assistant).
# 2. **AI Analysis:** The AI agent will analyze the user's input and generate a personalized travel profile, including recommendations for destinations, activities, and accommodations.
# 3. **Itinerary Builder:** The AI agent will then create a customized travel itinerary, taking into account factors such as travel time, budget, and user preferences.
# 4. **Real-time Booking:** Users can review and book their itinerary in real-time, with the AI agent handling all logistics, including flights, hotels, and activity reservations.
# 5. **Personalized Recommendations:** Throughout the trip, the AI agent will provide users with personalized recommendations for local experiences, restaurants, and attractions, based on their interests and preferences.
#
# **Key Features:**
#
# 1. **Customized Travel Profiles:** DreamScout will create unique travel profiles for each user, taking into account their interests, budget, and preferences.
# 2. **Real-time Booking and Logistics:** The AI agent will handle all booking and logistics, making it easy for users to plan and book their trips.
# 3. **Personalized Recommendations:** The AI agent will provide users with personalized recommendations for local experiences, restaurants, and attractions.
# 4. **Social Sharing:** Users can share their itineraries and travel experiences on social media, with the option to connect with other travelers who have similar interests.
# 5. **Travel Assistant:** The AI agent will be available to assist users throughout their trip, providing real-time support and answering any questions they may have.
#
# **Revenue Model:**
#
# 1. **Commission-based Bookings:** DreamScout will earn a commission on all bookings made through the platform.
# 2. **Subscription-based Model:** Users can subscribe to premium features, such as access to exclusive travel deals, personalized travel consulting, and priority customer support.
# 3. **Advertising:** The platform will display targeted advertisements from travel-related businesses, such as hotels, airlines, and tour operators.
#
# **Target Market:**
#
# 1. **Demographics:** Millennials and Gen Z travelers who are tech-savvy and interested in personalized travel experiences.
# 2. **Psychographics:** Travelers who value unique experiences, flexibility, and convenience.
# 3. **Geographics:** Urban, educated, and affluent individuals who have a high disposable income and are interested in exploring new destinations.
#
# **Competitive Advantage:**
#
# 1. **Personalized Travel Experiences:** DreamScout's AI-powered platform will provide users with highly personalized travel experiences, tailored to their interests and preferences.
# 2. **Convenience and Efficiency:** The platform will simplify the travel planning process, saving users time and effort.
# 3. **Real-time Support:** The AI agent will be available to assist users throughout their trip, providing real-time support and answering any questions they may have.
#
# **Marketing Strategy:**
#
# 1. **Social Media Marketing:** Utilize social media platforms to reach the target market, with a focus on Instagram, Facebook, and Twitter.
# 2. **Influencer Marketing:** Partner with social media influencers and travel bloggers to promote the platform.
# 3. **Content Marketing:** Create engaging content, such as travel guides, blog posts, and videos, to attract and retain users.
# 4. **Search Engine Optimization (SEO):** Optimize the platform's website and content for search engines, to improve visibility and drive organic traffic.
#
# **Launch Plan:**
#
# 1. **MVP Launch:** Launch a minimum viable product (MVP) version of the platform, with a limited set of features and a small user base.
# 2. **User Testing and Feedback:** Gather user feedback and iterate on the platform, adding new features and improvements.
# 3. **Full Launch:** Launch the full version of the platform, with all features and capabilities.
# 4. **Marketing and Promotion:** Execute the marketing strategy, promoting the platform to the target market and driving user acquisition.
